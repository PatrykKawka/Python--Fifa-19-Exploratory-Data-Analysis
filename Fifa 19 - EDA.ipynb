# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

df=pd.read_csv(r"C:\Users\pkawk\OneDrive\Pulpit\Patryk - materiały naukowe\Analiza danych i programowanie w Pythonie\Fifa19-EDA\fifa_eda.csv")
pd.set_option('display.max.columns', None)
display(df.head())
df.tail()
# Out:
#        ID               Name  Age Nationality  Overall  Potential  \
# 0  158023           L. Messi   31   Argentina       94         94
# 1   20801  Cristiano Ronaldo   33    Portugal       94         94
# 2  190871          Neymar Jr   26      Brazil       92         93
# 3  193080             De Gea   27       Spain       91         93
# 4  192985       K. De Bruyne   27     Belgium       91         92
#
#                   Club     Value   Wage Preferred Foot  \
# 0         FC Barcelona  110500.0  565.0           Left
# 1             Juventus   77000.0  405.0          Right
# 2  Paris Saint-Germain  118500.0  290.0          Right
# 3    Manchester United   72000.0  260.0          Right
# 4      Manchester City  102000.0  355.0          Right
#
#    International Reputation  Skill Moves Position  Joined  \
# 0                       5.0          4.0       RF    2004
# 1                       5.0          5.0       ST    2018
# ...

# %%
df.shape
# Out:
# (18207, 18)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 18207 entries, 0 to 18206
# Data columns (total 18 columns):
#  #   Column                    Non-Null Count  Dtype
# ---  ------                    --------------  -----
#  0   ID                        18207 non-null  int64
#  1   Name                      18207 non-null  object
#  2   Age                       18207 non-null  int64
#  3   Nationality               18207 non-null  object
#  4   Overall                   18207 non-null  int64
#  5   Potential                 18207 non-null  int64
#  6   Club                      17966 non-null  object
#  7   Value                     17955 non-null  float64
#  8   Wage                      18207 non-null  float64
#  9   Preferred Foot            18207 non-null  object
#  10  International Reputation  18159 non-null  float64
#  11  Skill Moves               18159 non-null  float64
#  12  Position                  18207 non-null  object
# ...

# %%
df.isnull().sum()
# Out:
# ID                            0
# Name                          0
# Age                           0
# Nationality                   0
# Overall                       0
# Potential                     0
# Club                        241
# Value                       252
# Wage                          0
# Preferred Foot                0
# International Reputation     48
# Skill Moves                  48
# Position                      0
# Joined                        0
# Contract Valid Until        289
# Height                        0
# Weight                        0
# Release Clause                0
# dtype: int64

# %%
#usuwanie pustych wierszy
df_cleaned = df.dropna()
df_cleaned.shape
# Out:
# (17955, 18)

# %%
df_cleaned.duplicated().sum()
#df_cleaned.dropduplicates()
# Out:
# 0

# %%
'''def country(x):
    return df[df['Nationality'] == x]

country('England').sort_values(by='Name')'''

english_players = df_cleaned.query('Nationality == "England"').sort_values(by='Name')
english_players.describe().T.style.background_gradient(cmap='Greens', axis = None)
# Out:
# <style type="text/css">
# #T_10eb9_row0_col0, #T_10eb9_row0_col3, #T_10eb9_row1_col0, #T_10eb9_row2_col0, #T_10eb9_row3_col0, #T_10eb9_row4_col0, #T_10eb9_row4_col1, #T_10eb9_row5_col0, #T_10eb9_row6_col0, #T_10eb9_row7_col0, #T_10eb9_row8_col0, #T_10eb9_row8_col1, #T_10eb9_row8_col3, #T_10eb9_row8_col4, #T_10eb9_row8_col5, #T_10eb9_row8_col6, #T_10eb9_row8_col7, #T_10eb9_row9_col0, #T_10eb9_row10_col0, #T_10eb9_row11_col0, #T_10eb9_row11_col5 {
#   background-color: #f6fcf4;
#   color: #000000;
# }
# #T_10eb9_row0_col1 {
#   background-color: #097532;
#   color: #f1f1f1;
# }
# #T_10eb9_row0_col2 {
#   background-color: #dff3da;
#   color: #000000;
# }
# #T_10eb9_row0_col4 {
#   background-color: #19833e;
#   color: #f1f1f1;
# }
# #T_10eb9_row0_col5 {
#   background-color: #016e2d;
#   color: #f1f1f1;
# }
# #T_10eb9_row0_col6 {
#   background-color: #005522;
#   color: #f1f1f1;
# }
# #T_10eb9_row0_col7 {
#   background-color: #00441b;
#   color: #f1f1f1;
# }
# ...

# %%
#wiodąca noga
english_players['Preferred Foot'].value_counts()
plt.figure(figsize=(5,5))
plt.hist(english_players['Preferred Foot'], color='Green', edgecolor='black', bins=2, width = 0.2, )

plt.show()
